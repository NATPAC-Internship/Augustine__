# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.dropna(subset=['Latitude', 'Longitude'], inplace=True)
#       2 X = df[['Latitude', 'Longitude']]
#       3 filtered_df = df[(df['Latitude'] >= 6) & (df['Latitude'] <= 14) & (df['Longitude'] >= 50) & (df['Longitude'] <= 84)]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\Linear_clu_pre\linear_alappuzha.csv')

# %%
df.dropna(subset=['Latitude', 'Longitude'], inplace=True)
X = df[['Latitude', 'Longitude']]
filtered_df = df[(df['Latitude'] >= 6) & (df['Latitude'] <= 14) & (df['Longitude'] >= 50) & (df['Longitude'] <= 84)]
X = filtered_df[['Latitude', 'Longitude']]

# %%
df.dropna(subset=['Latitude', 'Longitude'], inplace=True)
X = df[['Latitude', 'Longitude']]
filtered_df = df[(df['Latitude'] >= 6) & (df['Latitude'] <= 14) & (df['Longitude'] >= 50) & (df['Longitude'] <= 84)]
X = filtered_df[['Latitude', 'Longitude']]

# %%
num_clusters =4

# Perform KMeans clustering
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(X)

# Add cluster labels to the filtered dataframe
filtered_df['Cluster'] = kmeans.labels_

# Visualize the clusters
plt.scatter(filtered_df['Longitude'], filtered_df['Latitude'], c=filtered_df['Cluster'], cmap='viridis')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Clustering based on Coordinates (Filtered)')
plt.show()

# Save the updated dataframe with cluster labels and filtered data
# Out:
# c:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
filtered_df=pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\Linear_clu_pre\linear_alappuzha.csv')

# %%
import folium

# Create a Folium map centered around a specific location (e.g., mean latitude and longitude of your data)
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster (you can adjust this based on the number of clusters)
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_colors[row['Cluster']], icon_size=(25, 25)),  # Adjust icon_size here
                  popup=f'Cluster {row["Cluster"]}').add_to(mymap)

# Save the map as an HTML file
mymap.save('clll_map-v1.html')

# %%
import folium
import pandas as pd


filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(quantity):
    if quantity < 100:
        return (0, 0)
    elif quantity < 1000:
        return (5, 5)
    elif quantity < 5000:
        return (9, 9)
    elif quantity < 10000:
        return (13, 13)
    elif quantity < 50000:
        return (17, 17)
    elif quantity < 150000:
        return (20, 20)
    elif quantity < 100000:
        return (25, 25)
    elif quantity < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    cluster_color = cluster_colors[row['Cluster'] % len(cluster_colors)]  # Handle more clusters than colors
    icon_size = get_icon_size(row['Quantity'])
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),  # Adjust icon_size here
                  popup=f'Cluster {row["Cluster"]}, Quantity: {row["Quantity"]}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 44
#      42 # Add markers to the map for each data point
#      43 for index, row in filtered_df.iterrows():
# ---> 44     cluster_color = cluster_colors[row['Cluster'] % len(cluster_colors)]  # Handle more clusters than colors
#      45     icon_size = get_icon_size(row['Quantity'])
#      46     folium.Marker([row['Latitude'], row['Longitude']],
#      47                   icon=folium.Icon(color=cluster_color, icon_size=icon_size),  # Adjust icon_size here
#      48                   popup=f'Cluster {row["Cluster"]}, Quantity: {row["Quantity"]}').add_to(mymap)
#
# TypeError: list indices must be integers or slices, not numpy.float64

# %%
import folium
import pandas as pd

# Sample data for testing
data = {
    'Latitude': [40.7128, 34.0522, 51.5074],
    'Longitude': [-74.0060, -118.2437, -0.1278],
    'Cluster': [0, 1, 2],
    'Quantity': [1000, 50000, 250000]
}
filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(quantity):
    if quantity < 100:
        return (0, 0)
    elif quantity < 1000:
        return (5, 5)
    elif quantity < 5000:
        return (9, 9)
    elif quantity < 10000:
        return (13, 13)
    elif quantity < 50000:
        return (17, 17)
    elif quantity < 150000:
        return (20, 20)
    elif quantity < 100000:
        return (25, 25)
    elif quantity < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    cluster_color = cluster_colors[int(row['Cluster']) % len(cluster_colors)]  # Ensure cluster is cast to int
    icon_size = get_icon_size(row['Quantity'])
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),  # Adjust icon_size here
                  popup=f'Cluster {row["Cluster"]}, Quantity: {row["Quantity"]}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)

# %%
import folium
import pandas as pd


filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(amount):
    if amount < 100:
        return (0, 0)
    elif amount < 1000:
        return (5, 5)
    elif amount < 5000:
        return (9, 9)
    elif amount < 10000:
        return (13, 13)
    elif amount < 50000:
        return (17, 17)
    elif amount < 150000:
        return (20, 20)
    elif amount < 100000:
        return (25, 25)
    elif amount < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    cluster_color = cluster_colors[row['Cluster'] % len(cluster_colors)]  # Handle more clusters than colors
    icon_size = get_icon_size(row['Amount'])
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),  # Adjust icon_size here
                  popup=f'Cluster {row["Cluster"]}, Amount: {row["Amount"]}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 38
#      36 # Add markers to the map for each data point
#      37 for index, row in filtered_df.iterrows():
# ---> 38     cluster_color = cluster_colors[row['Cluster'] % len(cluster_colors)]  # Handle more clusters than colors
#      39     icon_size = get_icon_size(row['Amount'])
#      40     folium.Marker([row['Latitude'], row['Longitude']],
#      41                   icon=folium.Icon(color=cluster_color, icon_size=icon_size),  # Adjust icon_size here
#      42                   popup=f'Cluster {row["Cluster"]}, Amount: {row["Amount"]}').add_to(mymap)
#
# TypeError: list indices must be integers or slices, not numpy.float64

# %%
import folium
import pandas as pd



filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(amount):
    if amount < 100:
        return (0, 0)
    elif amount < 1000:
        return (5, 5)
    elif amount < 5000:
        return (9, 9)
    elif amount < 10000:
        return (13, 13)
    elif amount < 50000:
        return (17, 17)
    elif amount < 150000:
        return (20, 20)
    elif amount < 100000:
        return (25, 25)
    elif amount < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    # Ensure 'Cluster' is an integer and within range
    cluster_index = int(row['Cluster']) % len(cluster_colors)
    cluster_color = cluster_colors[cluster_index]
    
    icon_size = get_icon_size(row['Amount'])
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),
                  popup=f'Cluster {row["Cluster"]}, Amount: {row["Amount"]}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 43
#      40     cluster_index = int(row['Cluster']) % len(cluster_colors)
# ...

# %%
import folium
import pandas as pd



filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(amount):
    if amount < 100:
        return (0, 0)
    elif amount < 1000:
        return (5, 5)
    elif amount < 5000:
        return (9, 9)
    elif amount < 10000:
        return (13, 13)
    elif amount < 50000:
        return (17, 17)
    elif amount < 150000:
        return (20, 20)
    elif amount < 100000:
        return (25, 25)
    elif amount < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    # Ensure 'Cluster' is an integer and within range
    cluster_index = int(row['Cluster']) % len(cluster_colors)
    cluster_color = cluster_colors[cluster_index]
    
    # Use the correct column name for amount (replace 'Amount' with the actual column name)
    icon_size = get_icon_size(row['Amount'])  # Replace 'Amount' with the correct column name
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),
                  popup=f'Cluster {row["Cluster"]}, Amount: {row["Amount"]}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 44
#      41     cluster_color = cluster_colors[cluster_index]
# ...

# %%
import folium
import pandas as pd



filtered_df = pd.DataFrame(data)

# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
amount= filtered_df['2024'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(amount):
    if amount < 100:
        return (0, 0)
    elif amount < 1000:
        return (5, 5)
    elif amount < 5000:
        return (9, 9)
    elif amount < 10000:
        return (13, 13)
    elif amount < 50000:
        return (17, 17)
    elif amount < 150000:
        return (20, 20)
    elif amount < 100000:
        return (25, 25)
    elif amount < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    # Ensure 'Cluster' is an integer and within range
    cluster_index = int(row['Cluster']) % len(cluster_colors)
    cluster_color = cluster_colors[cluster_index]
    
    # Use the value in '2024' column as amount
    # amount = row['2024']  # Using '2024' column value as amount
    icon_size = get_icon_size(amount)
    
    # Add the amount to the popup message
    popup_message = f'Cluster {row["Cluster"]}, Amount: {amount}'
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),
                  popup=popup_message).add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2024'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 11
#       9 mean_latitude = filtered_df['Latitude'].mean()
# ...

# %%
import folium
import pandas as pd

# Assuming data is defined somewhere in your code



# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Define colors for each cluster
cluster_colors = ['red', 'blue', 'green', 'purple', 'orange']

# Function to map quantity values to icon sizes
def get_icon_size(amount):
    if amount < 100:
        return (0, 0)
    elif amount < 1000:
        return (5, 5)
    elif amount < 5000:
        return (9, 9)
    elif amount < 10000:
        return (13, 13)
    elif amount < 50000:
        return (17, 17)
    elif amount < 150000:
        return (20, 20)
    elif amount < 100000:
        return (25, 25)
    elif amount < 200000:
        return (30, 30)
    else:
        return (35, 35)

# Add markers to the map for each data point
for index, row in filtered_df.iterrows():
    # Ensure 'Cluster' is an integer and within range
    cluster_index = int(row['Cluster']) % len(cluster_colors)
    cluster_color = cluster_colors[cluster_index]
    
    # Use the value in '2024' column as amount
    amount = row['2024']  # Using '2024' column value as amount
    icon_size = get_icon_size(amount)
    
    # Add the amount to the popup message
    popup_message = f'Cluster {row["Cluster"]}, Amount: {amount}'
    folium.Marker([row['Latitude'], row['Longitude']], 
                  icon=folium.Icon(color=cluster_color, icon_size=icon_size),
                  popup=popup_message).add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)

# %%
import folium
import pandas as pd



# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5

# Add circles to the map for each data point
for index, row in filtered_df.iterrows():
    # Ensure 'Cluster' is an integer and within range
    cluster_index = int(row['Cluster']) % len(cluster_colors)
    cluster_color = cluster_colors[cluster_index]
    
    # Use the value in '2024' column as amount
    amount = row['2024']  # Using '2024' column value as amount
    circle_radius = get_circle_radius(amount)
    
    # Create a circle marker with flat style
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color=cluster_color, 
                        fill=True, 
                        fill_color=cluster_color, 
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)

# %%
import pandas as pd
filtered_df=pd.read_csv(r'C:\Users\augus\OneDrive\Desktop\js\Cargo predict\Export\Dataset\RandFro_clu_pre\randfrst_malappuram.csv')

# %%
import folium
import pandas as pd

# Assuming data is defined somewhere in your code



# Create a Folium map centered around the mean latitude and longitude
mean_latitude = filtered_df['Latitude'].mean()
mean_longitude = filtered_df['Longitude'].mean()
mymap = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=5)

# Function to map quantity values to circle sizes (radius)
def get_circle_radius(amount):
    if amount < 100:
        return .5
    elif amount < 1000:
        return 1.0
    elif amount < 5000:
        return 1.5
    elif amount < 10000:
        return 2.0
    elif amount < 50000:
        return 2.5
    elif amount < 150000:
        return 3.0
    elif amount < 100000:
        return 3.5
    elif amount < 200000:
        return 4.0
    else:
        return 4.5

# Add circles to the map for each data point
for index, row in filtered_df.iterrows():
    # Use the value in '2026' column as amount
    amount = row['2028']  # Using '2026' column value as amount
    circle_radius = get_circle_radius(amount)
    
    # Create a circle marker with flat style and blue color
    folium.CircleMarker([row['Latitude'], row['Longitude']], 
                        radius=circle_radius, 
                        color='blue',  # Set color to blue
                        fill=True, 
                        fill_color='blue',  # Set fill color to blue
                        fill_opacity=0.6,
                        popup=f'Cluster {row["Cluster"]}, Amount: {amount}').add_to(mymap)

# Save the map as an HTML file with a timestamp in the filename
timestamp = pd.Timestamp.now().strftime('%Y-%m-%d_%H-%M-%S')
filename = f'clll_map_{timestamp}.html'
mymap.save(filename)
